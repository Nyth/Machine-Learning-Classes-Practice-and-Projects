# %% [markdown]
# Load AI Model

# %%
import warnings as wr
wr.filterwarnings('ignore')
import pickle
reg=pickle.load(open('my_lr1','rb')) #read binary

# %%
reg.predict([[2000]])
# Out:
# array([[30915.19947746]])

# %%
reg2=jb.load('my_lr2')

# %%
reg2
# Out:
# LinearRegression()

# %%
reg2.predict([[3000]])
# Out:
# array([[52603.00586478]])

# %% [markdown]
# Feature Transformation

# %%
# Feature Transformation means in bengali Anupatic Transformation for example 122m=.122cm
#4 tupes of Techniques to Perform Feature Transformation
# 1)Normalization 2)Standardization 3)Robust Scaler 4)Max Absolute Scaler

# %%
import pandas as pd

# %%
df=pd.read_csv('Superstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# Normalization

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler() #MinMaxScaler(feature_range=(2,5))

# %%
df_sal=m.fit(df[['Sales']]) #training

# %%
df_sal
# Out:
# MinMaxScaler()

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df[['Sales']]=m.transform(df[['Sales']]) #transformation

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  0.011552         2
# 1        42420  South        Furniture       Chairs  0.032313         3
# 2        90036   West  Office Supplies       Labels  0.000626         2
# 3        33311  South        Furniture       Tables  0.042280         5
# 4        33311  South  Office Supplies      Storage  0.000968         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
#fit and Transform
df_dis=m.fit_transform(df[['Discount']]) #training and trasnform

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  0.011552         2
# 1        42420  South        Furniture       Chairs  0.032313         3
# 2        90036   West  Office Supplies       Labels  0.000626         2
# 3        33311  South        Furniture       Tables  0.042280         5
# 4        33311  South  Office Supplies      Storage  0.000968         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
#Differentiating Dependant and Independant variable
x=df.drop('Profit',axis=1)
y=df[['Profit']]

# %%
x.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  0.011552         2
# 1        42420  South        Furniture       Chairs  0.032313         3
# 2        90036   West  Office Supplies       Labels  0.000626         2
# 3        33311  South        Furniture       Tables  0.042280         5
# 4        33311  South  Office Supplies      Storage  0.000968         2
#
#    Discount
# 0      0.00
# 1      0.00
# 2      0.00
# 3      0.45
# 4      0.20

# %%
x1=x.copy()
x2=x.copy()
x3=x.copy()
x4=x.copy()
x5=x.copy()
x6=x.copy()
